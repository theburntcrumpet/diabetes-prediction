# %% [markdown]
# # Train Diabetes Model

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("diabetes_risk_prediction_dataset.csv")
data
# Out:
#      Age  Gender Polyuria  ... Alopecia Obesity     class
# 0     40    Male       No  ...      Yes     Yes  Positive
# 1     58    Male       No  ...      Yes      No  Positive
# 2     41    Male      Yes  ...      Yes      No  Positive
# 3     45    Male       No  ...       No      No  Positive
# 4     60    Male      Yes  ...      Yes     Yes  Positive
# ..   ...     ...      ...  ...      ...     ...       ...
# 515   39  Female      Yes  ...       No      No  Positive
# 516   48  Female      Yes  ...       No      No  Positive
# 517   58  Female      Yes  ...       No     Yes  Positive
# 518   32  Female       No  ...      Yes      No  Negative
# 519   42    Male       No  ...       No      No  Negative
#
# [520 rows x 17 columns]

# %%
yes_no_columns = [
    "Polyuria",
    "Polydipsia",
    "sudden weight loss",
    "weakness",
    "Polyphagia",
    "Genital thrush",
    "visual blurring",
    "Itching",
    "Irritability",
    "delayed healing",
    "partial paresis",
    "muscle stiffness",
    "Alopecia",
    "Obesity"
]

data["Gender"] = data["Gender"].replace({"Male": 0, "Female": 1})
data[yes_no_columns] = data[yes_no_columns].replace({"No": 0, "Yes": 1})
data["class"] = data["class"].replace({"Negative": 0, "Positive": 1})
data
# Out:
#      Age  Gender  Polyuria  ...  Alopecia  Obesity  class
# 0     40       0         0  ...         1        1      1
# 1     58       0         0  ...         1        0      1
# 2     41       0         1  ...         1        0      1
# 3     45       0         0  ...         0        0      1
# 4     60       0         1  ...         1        1      1
# ..   ...     ...       ...  ...       ...      ...    ...
# 515   39       1         1  ...         0        0      1
# 516   48       1         1  ...         0        0      1
# 517   58       1         1  ...         0        1      1
# 518   32       1         0  ...         1        0      0
# 519   42       0         0  ...         0        0      0
#
# [520 rows x 17 columns]

# %%
data_features = data.copy()
data_labels = data_features.pop("class")

# %%
diabetes_model = keras.Sequential([
    keras.layers.Normalization(),
    keras.layers.Dense(16),
    keras.layers.Dense(128),
    keras.layers.Dense(1, activation="sigmoid")
])

diabetes_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

diabetes_model.fit(data_features,data_labels,epochs=16)

diabetes_model.evaluate(data_features, data_labels)
# Out:
# Epoch 1/16
# 17/17 [==============================] - 0s 2ms/step - loss: 0.9040 - accuracy: 0.4673
# Epoch 2/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.7958 - accuracy: 0.5385
# Epoch 3/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6914 - accuracy: 0.5596
# Epoch 4/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6224 - accuracy: 0.6596
# Epoch 5/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5630 - accuracy: 0.7173
# Epoch 6/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5125 - accuracy: 0.7462
# Epoch 7/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4404 - accuracy: 0.8288
# Epoch 8/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3926 - accuracy: 0.8942
# Epoch 9/16
# 17/17 [==============================] - 0s 1ms/step - loss: 0.3598 - accuracy: 0.8904
# Epoch 10/16
# ...

# %%
result = diabetes_model.predict(np.array([40,0,0,1,0,1,0,0,0,1,0,1,0,1,1,1]))


diabetes_model.save("diabetes.keras")
result[0][0]
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 0.3956336
